# %%
import numpy as np 



olcumler=np.array([17,160,234,144,145,107,197,201,75,225,211,119,157,145,127,244,163,149,65,112,185,202,146,203,224,203,114,188,156,187,177,95,165,50,110,216,138,151,166,135,155,84,251,173,131,207,121,120])

# %%
olcumler[0:10]
# Out:
# array([ 17, 160, 234, 144, 145, 107, 197, 201,  75, 225])

# %%
import scipy.stats as stats

# %%
stats.describe(olcumler)
# Out:
# DescribeResult(nobs=48, minmax=(17, 251), mean=155.20833333333334, variance=2652.764184397163, skewness=-0.3621889669857958, kurtosis=-0.08744077060954414)

# %%
#varsayimlar
#normallık varsayimim

# %%
import pandas as pd 
#historgram
pd.DataFrame(olcumler).plot.hist();

# %%
#qqplot
import pylab
stats.probplot(olcumler,dist="norm",plot=pylab)
pylab.show()

# %%
#shapiro-wilks testi

# ho: örnek dağılımı ile teorik normal dapılımu arasında bir fark yoktur
# h1: fark vardır

# %%
from scipy.stats import shapiro

# %%
shapiro(olcumler)
# Out:
# ShapiroResult(statistic=0.9844962554630069, pvalue=0.7704497090937904)

# %%
print("T HESAP İSTATİSLİĞİ:"+str(shapiro(olcumler)[0]))
print("Hesaplanan p-value:"+str(shapiro(olcumler)[1]))
# Out:
# T HESAP İSTATİSLİĞİ:0.9844962554630069
# Hesaplanan p-value:0.7704497090937904

# %%
#hipotezin uygulanması

# %%
stats.ttest_1samp(olcumler,popmean=170)
# Out:
# TtestResult(statistic=-1.9897036990183188, pvalue=0.0524596715451559, df=47)

# %%
#ho:web sitemizde geçirilen ortalam sure 170
#h1:değiştiri

# %% [markdown]
# nanparametrik tek örneklem testi

# %%
from statsmodels.stats.descriptivestats import sign_test

# %%
sign_test(olcumler,170)
# Out:
# (-6.0, 0.11140289106101878)
